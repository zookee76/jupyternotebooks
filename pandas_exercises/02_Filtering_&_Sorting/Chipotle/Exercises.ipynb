# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
prod_more_10 = chipo[chipo['item_price'] > 10.00]
prod_more_10 = prod_more_10.drop_duplicates(['item_name', 'quantity'])
prod_more_10 = prod_more_10[prod_more_10['quantity'] == 1]
prod_more_10
# Out:
#       order_id  quantity              item_name  \
# 5            3         1           Chicken Bowl
# 7            4         1          Steak Burrito
# 23          12         1        Chicken Burrito
# 39          19         1          Barbacoa Bowl
# 57          26         1         Veggie Burrito
# 62          28         1            Veggie Bowl
# 79          35         1     Chicken Soft Tacos
# 90          40         1             Steak Bowl
# 93          41         1       Carnitas Burrito
# 97          43         1          Carnitas Bowl
# 130         57         1       Barbacoa Burrito
# 168         75         1  Barbacoa Crispy Tacos
# 186         83         1      Veggie Salad Bowl
# 250        109         1          Chicken Salad
# 365        158         1   Chicken Crispy Tacos
# 606        250         1       Steak Salad Bowl
# 738        304         1      Veggie Soft Tacos
# 988        406         1    Barbacoa Soft Tacos
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo[['item_name', 'item_price']]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by = 'item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
most_expensive_item = chipo[chipo['item_price'] == chipo['item_price'].max()]
most_expensive_item['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
vsb_orders = chipo[chipo['item_name'] == 'Veggie Salad Bowl']
vsb_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 186 to 4573
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            18 non-null     int64
#  1   quantity            18 non-null     int64
#  2   item_name           18 non-null     object
#  3   choice_description  18 non-null     object
#  4   item_price          18 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 864.0+ bytes

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
more_soda = chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)]
more_soda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 18 to 3866
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            20 non-null     int64
#  1   quantity            20 non-null     int64
#  2   item_name           20 non-null     object
#  3   choice_description  20 non-null     object
#  4   item_price          20 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 960.0+ bytes
